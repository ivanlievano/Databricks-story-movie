# %%
from pyspark.sql.functions import current_timestamp, lit, concat, col

# %%
movie_genre_df = spark.read \
                .option("inferSchema", "True") \
                .option("header", "True") \
                .json('/mnt/storymovie/bronze/movie_genre.json')

# %%
movie_genre_final = movie_genre_df \
                    .withColumnRenamed("genreId", "genre_id") \
                    .withColumnRenamed("movieId", "movie_id") \
                    .withColumn('ingestion_date', current_timestamp()) \
                    .withColumn('env', lit('python'))

# %%
movie_genre_final.write.mode('overwrite').partitionBy('movie_id').parquet('/mnt/storymovie/silver/movie_genres')

# %%
# %fs
ls /mnt/storymovie/silver/movie_genres
