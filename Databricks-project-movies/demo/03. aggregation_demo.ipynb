# %%
# %run "../includes/configuration"

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import count, countDistinct, sum, max, min, avg, rank, dense_rank, desc

# %%
gold_folder_path

# %%
movies_df = spark.read.parquet(f"{silver_folder_path}/movies")

# %%
display(movies_df)

# %%
movies_df.select(count("*").alias("conteos")).show()

# %%
movies_df.select(countDistinct("year_release_date").alias("conteos")).show()

# %%
movies_df.select(sum("budget").alias("sumatoria")).show()

# %%
movies_df.select(sum("budget").alias("sumatoria")).display()

# %%
movies_df.filter("year_release_date = 2016") \
        .select(sum("budget").alias("sum_budget"), count("movie_id").alias("movie_id")).display()

# %%
movies_df  \
    .groupBy("year_release_date") \
        .agg(sum("budget"),
             avg("budget"),
             max("budget"),
             min("budget"),
             count("movie_id")
             ) \
    .display()

# %% [markdown]
# ## Particion con Rank

# %%
movies_df.select("title", "budget", "year_release_date") \
                .filter("year_release_date > 1980 and year_release_date is not null") \
                .withColumn("rank", rank().over(Window.partitionBy("year_release_date").orderBy(desc("budget"))) ) \
                .display()

# %% [markdown]
# ## Particion con Dense Rank

# %%
movie_dense_rank = Window.partitionBy("year_release_date").orderBy(desc("budget"))

movies_df.select("title", "budget", "year_release_date") \
                .filter("year_release_date > 1980 and year_release_date is not null") \
                .withColumn("dense_rank", dense_rank().over(movie_dense_rank) ) \
                .display()
