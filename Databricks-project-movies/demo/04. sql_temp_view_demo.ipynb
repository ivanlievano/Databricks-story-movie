# %%
# %run "../includes/configuration"

# %%
results_movie = spark.read \
                .parquet(f"{gold_folder_path}/results_movie_genre_language")

# %%
results_movie.createOrReplaceTempView("r_movie")

# %%
# %sql
select *
from r_movie
where vote_average != 7.40

# %%
results_movie_2 = spark.sql("select * from r_movie")

# %% [markdown]
# - Vista ahora global

# %%
results_movie.createOrReplaceGlobalTempView("gr_movie")

# %%
# %sql
show tables

# %%
# %sql
show tables in global_temp

# %%
spark.table("global_temp.gr_movie").display()
